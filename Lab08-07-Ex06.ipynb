// %% [markdown]
// # Lab 8 Exercise 6
//
// ## Method with parameter

// %% [markdown]
// 1. สร้าง console application project
//
// ```
//     dotnet new console --name Lab08_Ex06
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// > 1. var mc = new MyClass();
// > 2. mc.DisplayParam(3, 4);
// > 3. class MyClass
// > 4. {
// > 5.     public void DisplayParam(int a, int b)
// > 6.     {
// > 7.         System.Console.WriteLine($"a = {a}, b = {b}");
// > 8.     }
// > 9. }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```
//     dotnet build  Lab08_Ex06
// ```

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```
//     dotnet run --project Lab08_Ex06
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// โค้ดใน Lab08_Ex06 สร้างคลาสที่มีตัวแปร a และ b และกำหนดค่าให้เป็น 3 และ 4 ตามลำดับ เมื่อรันโปรแกรมจะแสดงผล "a = 3, b = 4" แสดงว่าค่าของตัวแปรถูกกำหนดผ่าน explicit initialization หรือ constructor และทำงานได้ตามปกติ ไม่มีคำเตือนหรือข้อผิดพลาด

// %% [markdown]
// 8. นำ code ในข้อ 2 มารันบน polyglot notebook  โดยใส่ใน  code cell ด้านล่างนี้

// %%
var mc = new MyClass();
mc.DisplayParam(3, 4);
class MyClass
{
    public void DisplayParam(int a, int b)
    {
     System.Console.WriteLine($"a = {a}, b = {b}");
    } 
}
// Out:
// a = 3, b = 4

// %% [markdown]
// 8.1 ผลการรันเป็นอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// a = 3, b = 4

// %% [markdown]
// 8.2 เหมือนหรือต่างจาก console application อย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เหมือนกัน

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Method with parameter คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Method with Parameter คือเมธอดที่รับค่าภายนอก (parameter) มาประมวลผลเมื่อถูกเรียกใช้งาน

// %% [markdown]
// 2. ทำไมเราต้องใช้ parameter ใน method

// %% [markdown]
// *คำตอบ*

// %% [markdown]
//  เพื่อให้เมธอดสามารถทำงานกับค่าที่แตกต่างกันโดยไม่ต้องเขียนโค้ดซ้ำ

// %% [markdown]
// 3. parameter และ argument แตกต่างกันอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Parameter คือ ตัวแปรที่ประกาศในเมธอด (กำหนดไว้ตอนเขียนเมธอด)
// Argument คือ ค่าจริงที่ส่งเข้าไปในเมธอดตอนเรียกใช้งาน

// %% [markdown]
// 4. ส่วนประกอบของ method ที่มี parameter มีอะไรบ้าง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// 1. ชื่อเมธอด
// 2. ประเภทของค่าที่ส่งกลับ (Return Type)
// 3. รายการพารามิเตอร์ในวงเล็บ ()
// 4. โค้ดภายในบล็อก {}

// %% [markdown]
// 5. เมื่อไหร่ควรใช้ method ที่มี parameter

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// - เมื่อเมธอดต้องใช้ข้อมูลจากภายนอกเพื่อประมวลผล
//
// - เมื่อต้องการทำให้โค้ดยืดหยุ่นและใช้ซ้ำได้ง่าย

// %% [markdown]
// 6. ถ้าแก้ไขโค้ดในบรรทัดที่ 2 เป็นดังต่อไปนี้  จะได้ผลการ build หรือ run เป็นอย่างไร ให้แสดง output ที่โปรแกรมแสดงออกมา
// ```csharp
//     mc.DisplayParam(3.5, 4.2);
// ```

// %%
var mc = new MyClass();
mc.DisplayParam(3.5, 4.2);
class MyClass
{
    public void DisplayParam(int a, int b)
    {
        System.Console.WriteLine($"a = {a}, b = {b}");
    }
}
// Out:
// (2,17): error CS1503: Argument 1: cannot convert from 'double' to 'int'
//
// (2,22): error CS1503: Argument 2: cannot convert from 'double' to 'int'

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. ถ้าแก้ไขโค้ดในบรรทัดที่ 2 เป็นดังต่อไปนี้  จะได้ผลการ build หรือ run เป็นอย่างไร ให้แสดง output ที่โปรแกรมแสดงออกมา
// ```csharp
//     mc.DisplayParam("Hello", "World");
// ```

// %%
var mc = new MyClass();
mc.DisplayParam("Hello", "World");
class MyClass
{
    public void DisplayParam(int a, int b)
    {
        System.Console.WriteLine($"a = {a}, b = {b}");
    }
}
// Out:
// (2,17): error CS1503: Argument 1: cannot convert from 'string' to 'int'
//
// (2,26): error CS1503: Argument 2: cannot convert from 'string' to 'int'

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 8. จงเขียน method ที่ตรวจสอบว่าตัวเลขที่รับเข้ามาเป็นจำนวนคู่หรือจำนวนคี่ และแสดงผลลัพธ์ทางหน้าจอ

// %%
var mc = new MyClass();
mc.DisplayParam(3, 4); // ทดสอบฟังก์ชัน

class MyClass
{
    public void DisplayParam(int a, int b)
    {
        System.Console.WriteLine($"a = {a}, {CheckEvenOdd(a)}");
        System.Console.WriteLine($"b = {b}, {CheckEvenOdd(b)}");
    } 

    private string CheckEvenOdd(int num)
    {
        return (num % 2 == 0) ? "เป็นจำนวนคู่ (Even)" : "เป็นจำนวนคี่ (Odd)";
    }
}
// Out:
// a = 3, เป็นจำนวนคี่ (Odd)
// b = 4, เป็นจำนวนคู่ (Even)

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// a = 3, เป็นจำนวนคี่ (Odd)
// b = 4, เป็นจำนวนคู่ (Even)
